# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/Users/sa22/Documents/code/Music_recommedation_algorithm/data/raw/train.csv')

# %%
df.head()
# Out:
#    Unnamed: 0           artist_name            track_name  release_date genre  \
# 0           0                mukesh  mohabbat bhi jhoothi          1950   pop
# 1           4         frankie laine             i believe          1950   pop
# 2           6           johnnie ray                   cry          1950   pop
# 3          10           pérez prado              patricia          1950   pop
# 4          12  giorgos papadopoulos    apopse eida oneiro          1950   pop
#
#                                               lyrics  len    dating  violence  \
# 0  hold time feel break feel untrue convince spea...   95  0.000598  0.063746
# 1  believe drop rain fall grow believe darkest ni...   51  0.035537  0.096777
# 2  sweetheart send letter goodbye secret feel bet...   24  0.002770  0.002770
# 3  kiss lips want stroll charm mambo chacha merin...   54  0.048249  0.001548
# 4  till darling till matter know till dream live ...   48  0.001350  0.001350
#
# ...

# %%
df.shape
# Out:
# (28362, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28362 entries, 0 to 28361
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                28362 non-null  int64
#  1   artist_name               28362 non-null  object
#  2   track_name                28362 non-null  object
#  3   release_date              28362 non-null  int64
#  4   genre                     28362 non-null  object
#  5   lyrics                    28362 non-null  object
#  6   len                       28362 non-null  int64
#  7   dating                    28362 non-null  float64
#  8   violence                  28362 non-null  float64
#  9   world/life                28362 non-null  float64
#  10  night/time                28362 non-null  float64
#  11  shake the audience        28362 non-null  float64
#  12  family/gospel             28362 non-null  float64
# ...

# %%
df.describe().T
# Out:
#                             count          mean           std          min  \
# Unnamed: 0                28362.0  42948.166878  24747.811462     0.000000
# release_date              28362.0   1990.239652     18.486997  1950.000000
# len                       28362.0     73.030534     41.831605     1.000000
# dating                    28362.0      0.021110      0.052366     0.000291
# violence                  28362.0      0.118371      0.178658     0.000284
# world/life                28362.0      0.120984      0.172216     0.000291
# night/time                28362.0      0.057356      0.111892     0.000289
# shake the audience        28362.0      0.017418      0.040658     0.000284
# family/gospel             28362.0      0.017045      0.041968     0.000289
# romantic                  28362.0      0.048676      0.106071     0.000284
# communication             28362.0      0.076651      0.109497     0.000291
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'artist_name', 'track_name', 'release_date', 'genre',
#        'lyrics', 'len', 'dating', 'violence', 'world/life', 'night/time',
#        'shake the audience', 'family/gospel', 'romantic', 'communication',
#        'obscene', 'music', 'movement/places', 'light/visual perceptions',
#        'family/spiritual', 'sadness', 'feelings', 'topic', 'age'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# artist_name                 0
# track_name                  0
# release_date                0
# genre                       0
# lyrics                      0
# len                         0
# dating                      0
# violence                    0
# world/life                  0
# night/time                  0
# shake the audience          0
# family/gospel               0
# romantic                    0
# communication               0
# obscene                     0
# music                       0
# movement/places             0
# light/visual perceptions    0
# family/spiritual            0
# sadness                     0
# feelings                    0
# topic                       0
# age                         0
# dtype: int64

# %% [markdown]
# # Univariate Analysis

# %%
genre_counts = df['genre'].value_counts()
genre_counts
# Out:
# genre
# pop        7038
# country    5444
# blues      4603
# rock       4032
# jazz       3844
# reggae     2497
# hip hop     904
# Name: count, dtype: int64

# %%
plt.bar(genre_counts.index, genre_counts.values, color=['red', '#00e64d', 'blue', 'orange', '#5900b3', '#00e6e6', '#009933'])
plt.title('Number of songs by music genre', weight='bold')
plt.xlabel('Genre', weight='bold')
plt.ylabel('Number of songs', weight='bold')
plt.show()

# %% [markdown]
# Pop is the most common genre in the dataset, with just over 7000. Hip hop is the least common genre with only 904 songs.

# %%
# Gets the top 10 artists
top_10_artists = df['artist_name'].value_counts().head(10)
# Gets colors from sns
colors1 = sns.color_palette('viridis', len(top_10_artists))

plt.bar(top_10_artists.index, top_10_artists.values, color=colors1)
plt.title('Top 10 Artists by songs', weight='bold')
plt.xlabel('Artist', weight='bold')
# Rotates x axis labels to make it readable
plt.xticks(rotation=45)
plt.ylabel('Number of songs', weight='bold')
plt.show()

# %% [markdown]
# Johnny Cash has the most appearances in this dataset with 190. He is followed closely by Ella Fitzgerald with 188 and then Dean Martin is next with 146. That is a lot of songs for each of them, as there are many artists in the dataset with only one song. The top 10 are also all artists with their prime many years ago. Most of them are very iconic and most have long passed away, with Dolly Parton and Willie Nelson being notable exceptions (that I hopefully didn't just jinx).

# %%
topic_counts = df['topic'].value_counts()
topic_counts
# Out:
# topic
# sadness       6094
# violence      5707
# world/life    5419
# obscene       4881
# music         2303
# night/time    1823
# romantic      1523
# feelings       612
# Name: count, dtype: int64

# %%
colors2 = sns.color_palette('deep', len(topic_counts))

plt.bar(topic_counts.index, topic_counts.values, color=colors2)
plt.title('Topics by counts', weight='bold')
plt.xlabel('Topics', weight='bold')
plt.xticks(rotation=45)
plt.ylabel('Number of songs', weight='bold')
plt.show()

# %% [markdown]
# Sadness is the most common topic (a fact I find sad) with over 6000 counts and it is followed by violence with over 5700, which I think also isn't a good thing, unless it's a therapeutic way to handle those things. Feelings is the least common and romantic is second least, which I find surprising as romantic would have been my guess to be number 1 before I saw this.

# %%
sns.histplot(data=df, x='release_date', kde=True)
plt.title('Number of songs by release dates', weight='bold')
plt.xlabel('Year of release', weight='bold')
plt.ylabel('Number of songs', weight='bold')
plt.show()

# %% [markdown]
# The dataset is almost evenly distributed with older songs being a bit less common and a few spikes in between. The last year shown in the dataset has the most songs and the 1950s have the least amount of songs.

# %%
sns.histplot(data=df, x='age', kde=True, color='green')
plt.title('Number by Age', weight='bold')
plt.xlabel('Age range (0 = Younger, 1 = Older)', weight='bold')
plt.ylabel('Counts of songs', weight='bold')
plt.show()

# %% [markdown]
# Much like the release_date column from earlier, this age column histplot show that this dataset is almost evenly distrubuted, with older songs being less common. Age can be seen as a mirror image of release_date that was normalized.

# %%
sns.histplot(data=df, x='len', color='red', kde=True)
plt.title('Length of songs', weight='bold')
plt.xlabel('Number of words in a song', weight='bold')
plt.ylabel('Song count', weight='bold')
plt.show()

# %% [markdown]
# This histplot is right skewed, most songs are in the 25 thru 85 word range. The highest in the dataset have 199 words and the lowest amount of words is 1.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'artist_name', 'track_name', 'release_date', 'genre',
#        'lyrics', 'len', 'dating', 'violence', 'world/life', 'night/time',
#        'shake the audience', 'family/gospel', 'romantic', 'communication',
#        'obscene', 'music', 'movement/places', 'light/visual perceptions',
#        'family/spiritual', 'sadness', 'feelings', 'topic', 'age'],
#       dtype='object')

# %% [markdown]
# # Bivariate Analysis

# %%
sns.pointplot(data=df, x='genre', y='len', color='red')
plt.title('Number of words in song by genre', weight='bold')
plt.xlabel('\nGenre', weight='bold')
plt.ylabel('Number of Words', weight='bold')
plt.show()

# %% [markdown]
# Reggae and hip hop tend to have a lot more words per song than all other genres, close to each other. Country, blues, and rock, have on average a lot less words than the other genres, with jazz slightly ahead.

# %%
sns.pointplot(data=df, x='topic', y='len', color='blue')
plt.title('Number of words in song by topic', weight='bold')
plt.xlabel('Topic', weight='bold')
plt.xticks(rotation=45)
plt.ylabel('Number of Words', weight='bold')
plt.show()

# %% [markdown]
# Obscene stands out here with by far the most words per song. Perhaps hip hop songs are the cause since most have many words, and are typically very obscene.

# %%
plt.figure(figsize=(15,6))
sns.countplot(data=df, x='genre', hue='release_date', palette='husl')
plt.title('Song counts of genres by release years', weight='bold')
plt.xlabel('\nGenres', weight='bold')
plt.ylabel('Counts of songs', weight='bold')
plt.legend(title='Release Years')
plt.show()

# %% [markdown]
# There aren't many songs in this dataset from the 50's which explains why none of the genres appear to have much popularity there. Pop stays consistently popular throughout the years, as the name implies, it is always popular.
#
# Blues stays fairly popular throught time and shows a late spike in the number of songs.
#
# Reggea has no data before the late 60's which tracks with the creation of reggae being considered around 1967.
#
# Rock shows a rise in popularity in the 80's which also makes sense with the rise of all the sub-genres of rock around that era.
#
# Hip hop is considered to have been created in the late 70's but the data for this genre begins in the 90's. Even then, there is hardly any data for hip hop until the 2010's and then a gigantic rise in popularity late in the decade that even rivals pop.

# %%
plt.figure(figsize=(15,6))
sns.countplot(data=df, x='topic', hue='release_date', palette='viridis')
plt.title('Topics by release years', weight='bold')
plt.xlabel('\nTopics', weight='bold')
plt.ylabel('Counts of songs', weight='bold')
plt.legend(title='Release Years')
plt.show()

# %% [markdown]
# Here we see that romantic has been dying down, violence has risen greatly, and that obscene has had an enormous upward trend and ends the years shown with a gigantic spike. Night/time and especially feelings are never very popular throughout the years.

# %%
plt.figure(figsize=(15,6))
sns.countplot(data=df, x='topic', hue='genre', palette='Spectral')
plt.title('Genres by Topics', weight='bold')
plt.xlabel('\nTopics', weight='bold')
plt.ylabel('Number of songs', weight='bold')
plt.legend(title='Genres')
plt.show()

# %% [markdown]
# Pop stands out in most categories but that is likely because there are more pop songs than anything in the dataset. Hip hop is definitely very obscene as it is hardly present in any topics, and then it is very visible within obscene.
#
# Blues is shockingly larger in violence than in sadness. Perhaps "feeling the blues" should actually be redefined to mean that you are feeling very violent.
#
# Rock stands out in violence which also makes sense, particularly within certain subgenres such as heavy metal and grunge would likely be described as violent by most people.
#
# Country nearly rivals pop in sadness, which have the highest count of genres withing topics.

# %%
sns.lineplot(data=df, x='age', y='len', color='#30e6b5')
plt.title('Song age by length', weight='bold')
plt.xlabel('\nAge (0 is newer, 1 is older)', weight='bold')
plt.ylabel('Number of words in songs', weight='bold')
plt.show()

# %% [markdown]
# This shows a clear trend that newer songs have more words in them.

# %%
top_10_artists2 = df['artist_name'].value_counts().head(10).index

top_artists_df = df[df['artist_name'].isin(top_10_artists2)]

plt.figure(figsize=(12, 7))
sns.countplot(data=top_artists_df, x='genre', hue='artist_name')
plt.title('Top 10 Artists by Genre\n', fontsize=15, weight='bold')
plt.xlabel("\nGenre", weight='bold')
plt.ylabel("Song Count\n", weight='bold')
plt.show()

# %% [markdown]
# The top 10 artists contribute only to 4 genres and overwhelmingly it is country. Ella Fitzgerald and Nina Simone are each contributing to more than one genre each, both to blues and jazz. Only Elvis is contributing to rock from the top 10.

# %%
plt.figure(figsize=(12, 7))
sns.countplot(data=top_artists_df, x='topic', hue='artist_name', order=top_artists_df['topic'].value_counts().index)
plt.title('Top 10 Artists by Topic\n', fontsize=15, weight='bold')
plt.xlabel("\nTopic", weight='bold')
plt.ylabel("Song Count\n", weight='bold')
plt.show()

# %% [markdown]
# It seems that for topics, the top 10 artists are contributing very consistently for all of them. Although sadness is still at the top, now world/life is number 2 as opposed to the overall artists dataset with violence at 2. Music and romantic have also moved up, but feelings is still clearly last.

# %% [markdown]
# # Multivariate Analysis

# %%
correlation_matrix = df.corr(numeric_only = True)

plt.figure(figsize=(20,10))
sns.heatmap(correlation_matrix, annot=True, cmap = 'coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# There isn't a strong correlation between any of the numerical values in the dataset. Obscene and length have the strongest and it's 0.44. This also tracks with hip hop having a longer length of songs and being obscene. Age and release_date have a -1 correlation since, as mentioned earlier, they are effectively mirror images.

# %%
# Groups by decade
df['decade'] = (df['release_date'] // 10) * 10

# Adds s to the end of the decade (e.g. 1990s)
df['decade'] = df['decade'].astype(str) + 's'

# Groups and simplifies
grouped = df.groupby(['decade', 'genre', 'topic']).size().reset_index(name='count')

g = sns.catplot(
    data=grouped,
    x='decade',
    y='count',
    hue='topic',
    col='genre',
    kind='point',
    col_wrap=4,
    palette='husl'
)

g.figure.suptitle("Genres and Topics through the years", fontsize=40, fontweight='bold', x=0.5, y=1.1)
for ax in g.axes.flat:
    ax.set_title(ax.get_title(), fontsize=20, fontweight='bold')
    ax.set_xlabel("Years", fontsize=20, fontweight='bold')
    ax.set_ylabel("Number of Songs", fontsize=20, fontweight='bold')

    ax.tick_params(axis='x', labelsize=15)
    ax.tick_params(axis='y', labelsize=20)

legend = g._legend
# Sets legend title and label font sizes
legend.set_title("Topic", prop={'size': 30, 'weight': 'bold'})
for text in legend.get_texts():
    text.set_fontsize(22)  # label size

# Moves the legend
g._legend.set_bbox_to_anchor((.89, 0.11))
g._legend.set_loc("lower right")

# %% [markdown]
# Here we see the popularity of the genres and their topics through the years. Most have a good mix of the topics but hip hop is only present in the 80s onward and obscene completely dominates the genre as a topic, it hardly represents any of the other topics.
#
# Pop has a huge spike in obscene from the 2000s onward.
#
# Country had sadness a dominant topic, until the 90s and then obscene rose ever since.
#
# Rock has violence as the major topic since the 70s and so has blues.
